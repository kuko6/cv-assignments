# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./cat.jpg')
#cv2.imshow('Image', img)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) # treba to zmenit na rgb

# %%
img = cv2.imread('zadanie1/pena.tif')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) # treba to zmenit na rgb
